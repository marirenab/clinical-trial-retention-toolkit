# %%
import pandas as pd
import numpy as np
import csv
import json
from typing import List, Optional
from pydantic import BaseModel, Field

# %%
common_description_yesno = {
    'type': 'string',
    'enum': ['Yes', 'No', 'NaN'],
    'description': 'Presence of {} (Yes/No). Use NaN if not found.'
}

common_description_numbers= {
    'type': 'integer',
    'description': 'Presence of {} (Yes/No). Use NaN if not found.'
}




class Entities(BaseModel):
    age: Optional[int] = Field(type='integer', description='Mean age of participants. Use NaN if not found')
    male: Optional[str] = Field(type='integer', description='Number of male participants. Use the word "NaN" if gender cannot be found.')
    female: Optional[str] = Field(type='integer', description='Number of female participants. Use the word "NaN" if gender cannot be found.')
    Asian: Optional[str] = Field(**common_description)
    Placebo: Field(**common_description)
    
    Native_Hawaiian_or_Other_Pacific_Islander : Optional[str] = Field(**common_description)
    Black_or_African_American =: Optional[str] = Field(**common_description)
    White = Field(**common_description)
    More_than_one_race =  Field(**common_description)
    STARTED = Field(type='integer', description='Number of participants that started trial. Use NaN if not found')
    COMPLETED= (type='integer', description='Number of participants that completed trial. Use NaN if not found')
    NOT_COMPLETED = (type='integer', description='Number of participants that did not complete the trial. Use NaN if not found')
    Awake: Optional[str] = Field(**common_description)
    Asleep: Optional[str] = Field(**common_description)
    Schizophrenia: Optional[str] = Field(**common_description)
    Psychosis: Optional[str] = Field(**common_description)
    Depression: Optional[str] = Field(**common_description)
    Anxiety: Optional[str] = Field(**common_description)
    Statin: Optional[str] = Field(**common_description)
    Simvastatin: Optional[str] = Field(**common_description)
    Atorvastatin: Optional[str] = Field(**common_description)
    Lipitor: Optional[str] = Field(**common_description)
    Phenytoin: Optional[str] = Field(**common_description)
    Anti_convulsants: Optional[str] = Field(**common_description)
    Anti_epileptic_drugs: Optional[str] = Field(**common_description)
    Dilantin: Optional[str] = Field(**common_description)
    Sodium_channel_blockers: Optional[str] = Field(**common_description)
    Medications: Optional[str] = Field(description='Extract list of medications from the text')

# %%
common_description = {
    'type': 'string',
    'enum': ['Yes', 'No', 'NaN'],
    'description': 'Presence of {} (Yes/No). Use NaN if not found.'
}
class Entities(BaseModel):
    age: Optional[int] = Field(type='integer', description='Age of the person. Use NaN if not found')
    gender: Optional[str] = Field(type='string', enum = ['Male', 'Female', 'NaN'], description='Gender of the person (Male/Female). Use the word "NaN" if gender cannot be found.')
    Epilepsy: Optional[str] = Field(**common_description)
    Seizures: Optional[str] = Field(**common_description)
    Awake: Optional[str] = Field(**common_description)
    Asleep: Optional[str] = Field(**common_description)
    Schizophrenia: Optional[str] = Field(**common_description)
    Psychosis: Optional[str] = Field(**common_description)
    Depression: Optional[str] = Field(**common_description)
    Anxiety: Optional[str] = Field(**common_description)
    Statin: Optional[str] = Field(**common_description)
    Simvastatin: Optional[str] = Field(**common_description)
    Atorvastatin: Optional[str] = Field(**common_description)
    Lipitor: Optional[str] = Field(**common_description)
    Phenytoin: Optional[str] = Field(**common_description)
    Anti_convulsants: Optional[str] = Field(**common_description)
    Anti_epileptic_drugs: Optional[str] = Field(**common_description)
    Dilantin: Optional[str] = Field(**common_description)
    Sodium_channel_blockers: Optional[str] = Field(**common_description)
    Medications: Optional[str] = Field(description='Extract list of medications from the text')

# %%
from pydantic import BaseModel, Field

schema = Entities.schema()

responses = []
for i in range(len(df)):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": df['text'][i]},
        ],
        functions=[
            {
                'name': 'extract_entities_from_text',
                'description': 'Your task is to parse the provided text into a .csv format, with a header row that lists the entities to extract, followed by a second row, with the extracted values, using the following schema',
                'parameters': Entities.schema()
            }
        ],
        function_call="auto",
    )
    if response.choices[0].message.function_call:
        json_response = json.loads(response.choices[0].message.function_call.arguments)
        responses.append(json_response)
for json_response in responses:
    entities_data = Entities(**json_response)
    print(entities_data.dict())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3 schema = Entities.schema()
#       5 responses = []
# ----> 6 for i in range(len(df)):
#       7     response = client.chat.completions.create(
#       8         model="gpt-3.5-turbo",
#       9         messages=[
#    (...)
#      19         function_call="auto",
#      20     )
#      21     if response.choices[0].message.function_call:
#
# NameError: name 'df' is not defined

# %%
schema = Entities.schema()
